-- %% [markdown]
-- # [QuanComTNUT]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [QuanComTNUT]    Script Date: 26/11/2025 9:35:25 CH ******/
CREATE DATABASE [QuanComTNUT]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'QuanComTNUT', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLSV\MSSQL\DATA\QuanComTNUT.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'QuanComTNUT_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLSV\MSSQL\DATA\QuanComTNUT_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [QuanComTNUT] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [QuanComTNUT].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [QuanComTNUT] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [QuanComTNUT] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [QuanComTNUT] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [QuanComTNUT] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [QuanComTNUT] SET ARITHABORT OFF 
GO
ALTER DATABASE [QuanComTNUT] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [QuanComTNUT] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [QuanComTNUT] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [QuanComTNUT] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [QuanComTNUT] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [QuanComTNUT] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [QuanComTNUT] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [QuanComTNUT] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [QuanComTNUT] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [QuanComTNUT] SET  ENABLE_BROKER 
GO
ALTER DATABASE [QuanComTNUT] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [QuanComTNUT] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [QuanComTNUT] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [QuanComTNUT] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [QuanComTNUT] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [QuanComTNUT] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [QuanComTNUT] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [QuanComTNUT] SET RECOVERY FULL 
GO
ALTER DATABASE [QuanComTNUT] SET  MULTI_USER 
GO
ALTER DATABASE [QuanComTNUT] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [QuanComTNUT] SET DB_CHAINING OFF 
GO
ALTER DATABASE [QuanComTNUT] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [QuanComTNUT] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [QuanComTNUT] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [QuanComTNUT] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'QuanComTNUT', N'ON'
GO
ALTER DATABASE [QuanComTNUT] SET QUERY_STORE = ON
GO
ALTER DATABASE [QuanComTNUT] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[ChiTietDonHang]

-- %%
USE [QuanComTNUT]
GO

-- %%
/****** Object:  Table [dbo].[ChiTietDonHang]    Script Date: 26/11/2025 9:35:25 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ChiTietDonHang](
	[MaDH] [int] NOT NULL,
	[MaMon] [int] NOT NULL,
	[SoLuong] [int] NULL,
	[DonGia] [decimal](10, 2) NULL,
PRIMARY KEY CLUSTERED 
(
	[MaDH] ASC,
	[MaMon] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DanhGia]

-- %%
/****** Object:  Table [dbo].[DanhGia]    Script Date: 26/11/2025 9:35:25 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DanhGia](
	[MaDG] [int] IDENTITY(1,1) NOT NULL,
	[MaDH] [int] NULL,
	[MaMon] [int] NULL,
	[MaKH] [int] NULL,
	[SoSao] [int] NULL,
	[BinhLuan] [nvarchar](max) NULL,
	[NgayDanhGia] [datetime] NULL,
	[AdminResponse] [nvarchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[MaDG] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DanhMuc]

-- %%
/****** Object:  Table [dbo].[DanhMuc]    Script Date: 26/11/2025 9:35:25 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DanhMuc](
	[MaDM] [int] IDENTITY(1,1) NOT NULL,
	[TenDM] [nvarchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[MaDM] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DonHang]

-- %%
/****** Object:  Table [dbo].[DonHang]    Script Date: 26/11/2025 9:35:25 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DonHang](
	[MaDH] [int] IDENTITY(1,1) NOT NULL,
	[MaKH] [int] NULL,
	[NguoiXuLy] [int] NULL,
	[TenNguoiNhan] [nvarchar](100) NULL,
	[SDTNguoiNhan] [varchar](15) NULL,
	[DiaChiGiao] [nvarchar](255) NULL,
	[GhiChu] [nvarchar](max) NULL,
	[TongTien] [decimal](10, 2) NULL,
	[PhuongThucTT] [nvarchar](50) NULL,
	[TrangThaiDon] [nvarchar](50) NULL,
	[NgayDat] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[MaDH] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MonAn]

-- %%
/****** Object:  Table [dbo].[MonAn]    Script Date: 26/11/2025 9:35:25 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MonAn](
	[MaMon] [int] IDENTITY(1,1) NOT NULL,
	[TenMon] [nvarchar](100) NOT NULL,
	[MoTa] [nvarchar](max) NULL,
	[Gia] [decimal](10, 2) NULL,
	[HinhAnh] [nvarchar](500) NULL,
	[MaDM] [int] NULL,
	[IsHienThi] [bit] NULL,
	[TrangThaiDuyet] [nvarchar](50) NULL,
	[NguoiTao] [int] NULL,
	[NgayTao] [datetime] NULL,
	[TrangThai] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[MaMon] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaiKhoan]

-- %%
/****** Object:  Table [dbo].[TaiKhoan]    Script Date: 26/11/2025 9:35:25 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaiKhoan](
	[MaTK] [int] IDENTITY(1,1) NOT NULL,
	[TenDangNhap] [varchar](50) NOT NULL,
	[MatKhau] [varchar](100) NOT NULL,
	[HoTen] [nvarchar](100) NOT NULL,
	[SDT] [varchar](15) NULL,
	[DiaChi] [nvarchar](255) NULL,
	[MaVaiTro] [int] NULL,
	[TrangThai] [bit] NULL,
	[NgayTao] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[MaTK] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[TenDangNhap] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[SDT] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[VaiTro]

-- %%
/****** Object:  Table [dbo].[VaiTro]    Script Date: 26/11/2025 9:35:25 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[VaiTro](
	[MaVaiTro] [int] NOT NULL,
	[TenVaiTro] [nvarchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[MaVaiTro] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__DanhGia__NgayDan__59063A47]

-- %%
ALTER TABLE [dbo].[DanhGia] ADD  DEFAULT (getdate()) FOR [NgayDanhGia]
GO

-- %% [markdown]
-- # [DF__DonHang__TongTie__4BAC3F29]

-- %%
ALTER TABLE [dbo].[DonHang] ADD  DEFAULT ((0)) FOR [TongTien]
GO

-- %% [markdown]
-- # [DF__DonHang__TrangTh__4CA06362]

-- %%
ALTER TABLE [dbo].[DonHang] ADD  DEFAULT (N'Chờ xác nhận') FOR [TrangThaiDon]
GO

-- %% [markdown]
-- # [DF__DonHang__NgayDat__4D94879B]

-- %%
ALTER TABLE [dbo].[DonHang] ADD  DEFAULT (getdate()) FOR [NgayDat]
GO

-- %% [markdown]
-- # [DF__MonAn__IsHienThi__440B1D61]

-- %%
ALTER TABLE [dbo].[MonAn] ADD  DEFAULT ((1)) FOR [IsHienThi]
GO

-- %% [markdown]
-- # [DF__MonAn__TrangThai__44FF419A]

-- %%
ALTER TABLE [dbo].[MonAn] ADD  DEFAULT (N'Chờ duyệt') FOR [TrangThaiDuyet]
GO

-- %% [markdown]
-- # [DF__MonAn__NgayTao__46E78A0C]

-- %%
ALTER TABLE [dbo].[MonAn] ADD  DEFAULT (getdate()) FOR [NgayTao]
GO

-- %% [markdown]
-- # [DF__MonAn__TrangThai__59FA5E80]

-- %%
ALTER TABLE [dbo].[MonAn] ADD  DEFAULT (N'Còn hàng') FOR [TrangThai]
GO

-- %% [markdown]
-- # [DF__TaiKhoan__TrangT__3C69FB99]

-- %%
ALTER TABLE [dbo].[TaiKhoan] ADD  DEFAULT ((1)) FOR [TrangThai]
GO

-- %% [markdown]
-- # [DF__TaiKhoan__NgayTa__3D5E1FD2]

-- %%
ALTER TABLE [dbo].[TaiKhoan] ADD  DEFAULT (getdate()) FOR [NgayTao]
GO

-- %% [markdown]
-- # [FK__ChiTietDo__MaMon__5165187F]

-- %%
ALTER TABLE [dbo].[ChiTietDonHang]  WITH CHECK ADD FOREIGN KEY([MaMon])
REFERENCES [dbo].[MonAn] ([MaMon])
GO

-- %% [markdown]
-- # [FK__ChiTietDon__MaDH__5070F446]

-- %%
ALTER TABLE [dbo].[ChiTietDonHang]  WITH CHECK ADD FOREIGN KEY([MaDH])
REFERENCES [dbo].[DonHang] ([MaDH])
GO

-- %% [markdown]
-- # [FK__DanhGia__MaDH__5535A963]

-- %%
ALTER TABLE [dbo].[DanhGia]  WITH CHECK ADD FOREIGN KEY([MaDH])
REFERENCES [dbo].[DonHang] ([MaDH])
GO

-- %% [markdown]
-- # [FK__DanhGia__MaKH__571DF1D5]

-- %%
ALTER TABLE [dbo].[DanhGia]  WITH CHECK ADD FOREIGN KEY([MaKH])
REFERENCES [dbo].[TaiKhoan] ([MaTK])
GO

-- %% [markdown]
-- # [FK__DanhGia__MaMon__5629CD9C]

-- %%
ALTER TABLE [dbo].[DanhGia]  WITH CHECK ADD FOREIGN KEY([MaMon])
REFERENCES [dbo].[MonAn] ([MaMon])
GO

-- %% [markdown]
-- # [FK__DonHang__MaKH__49C3F6B7]

-- %%
ALTER TABLE [dbo].[DonHang]  WITH CHECK ADD FOREIGN KEY([MaKH])
REFERENCES [dbo].[TaiKhoan] ([MaTK])
GO

-- %% [markdown]
-- # [FK__DonHang__NguoiXu__4AB81AF0]

-- %%
ALTER TABLE [dbo].[DonHang]  WITH CHECK ADD FOREIGN KEY([NguoiXuLy])
REFERENCES [dbo].[TaiKhoan] ([MaTK])
GO

-- %% [markdown]
-- # [FK__MonAn__MaDM__4316F928]

-- %%
ALTER TABLE [dbo].[MonAn]  WITH CHECK ADD FOREIGN KEY([MaDM])
REFERENCES [dbo].[DanhMuc] ([MaDM])
GO

-- %% [markdown]
-- # [FK__MonAn__NguoiTao__45F365D3]

-- %%
ALTER TABLE [dbo].[MonAn]  WITH CHECK ADD FOREIGN KEY([NguoiTao])
REFERENCES [dbo].[TaiKhoan] ([MaTK])
GO

-- %% [markdown]
-- # [FK__TaiKhoan__MaVaiT__3B75D760]

-- %%
ALTER TABLE [dbo].[TaiKhoan]  WITH CHECK ADD FOREIGN KEY([MaVaiTro])
REFERENCES [dbo].[VaiTro] ([MaVaiTro])
GO

-- %% [markdown]
-- # [CK__ChiTietDo__SoLuo__52593CB8]

-- %%
ALTER TABLE [dbo].[ChiTietDonHang]  WITH CHECK ADD CHECK  (([SoLuong]>(0)))
GO

-- %% [markdown]
-- # [CK__DanhGia__SoSao__5812160E]

-- %%
ALTER TABLE [dbo].[DanhGia]  WITH CHECK ADD CHECK  (([SoSao]>=(1) AND [SoSao]<=(5)))
GO

-- %% [markdown]
-- # [CK__MonAn__Gia__4222D4EF]

-- %%
ALTER TABLE [dbo].[MonAn]  WITH CHECK ADD CHECK  (([Gia]>=(0)))
GO

-- %% [markdown]
-- # [QuanComTNUT]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [QuanComTNUT] SET  READ_WRITE 
GO
